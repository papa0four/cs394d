# %% [markdown]
# ## Lecture 2.7: Linear Regression in PyTorch

# %%
import torchvision
import torch
from PIL import Image
## Create a vector pf zeros of size 5
size = (128, 128)
transform = torchvision.transforms.Compose([torchvision.tranforms.Resize(size), torchvision.transforms.ToTensor()])
